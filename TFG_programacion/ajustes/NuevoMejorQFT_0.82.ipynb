# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
from datetime import datetime
from IPython.display import clear_output

#Circuitos
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, Aer, transpile
from qiskit.quantum_info.operators import Operator, Pauli
from qiskit.quantum_info.operators.predicates import is_unitary_matrix
from qiskit.quantum_info import SparsePauliOp # Necesito un obsevable en concreto...

from qiskit.algorithms.optimizers import COBYLA, L_BFGS_B
from qiskit.circuit import Parameter
from qiskit.circuit.library import RealAmplitudes, ZFeatureMap, ZZFeatureMap, QFT
from qiskit.circuit import ParameterVector
from qiskit.utils import algorithm_globals


from sklearn.preprocessing import MinMaxScaler


from qiskit_machine_learning.algorithms.classifiers import NeuralNetworkClassifier, VQC
from qiskit_machine_learning.algorithms.regressors import NeuralNetworkRegressor, VQR
from qiskit_machine_learning.neural_networks import SamplerQNN, EstimatorQNN

# %%
df=pd.read_csv('./datos/AirPassengers.csv')
df['Month']=pd.to_datetime(df['Month'], infer_datetime_format=True)
df=df.set_index(['Month'])

df_log=np.log(df)
data_shift=df_log-df_log.shift()
data_shift = data_shift.dropna()

# %%
ptrain=0.8
pasajeros = np.array(data_shift['#Passengers'])
pasajeros_train = pasajeros[:int(pasajeros.shape[0]*0.8)]
pasajeros_test = pasajeros[int(pasajeros.shape[0]*0.8):]

# %%
window = 12;
tam_train = pasajeros_train.shape[0] - window
tam_test = pasajeros_test.shape[0] - window

conjunto_train = []
objetivo_train = []

conjunto_test = []
objetivo_test = []

for i in range(0,tam_train):
    conjunto_train.append(pasajeros_train[0+i:window+i])
    objetivo_train.append(pasajeros_train[window+i])
    
for i in range(0,tam_test):
    conjunto_test.append(pasajeros_test[0+i:window+i])
    objetivo_test.append(pasajeros_test[window+i])

objetivo_train = np.array(objetivo_train)
conjunto_train = np.array(conjunto_train)

objetivo_test = np.array(objetivo_test)
conjunto_test = np.array(conjunto_test)

# %%
scaler = MinMaxScaler((0.3, np.pi-0.3))
conjunto_train = scaler.fit_transform(conjunto_train)

# %%
objetivo_train = (-1.6/(np.min(objetivo_train) - np.max(objetivo_train)))*objetivo_train - 0.8 + np.min(objetivo_train)*(1.6/(np.min(objetivo_train) - np.max(objetivo_train)))
plt.plot(objetivo_train)
plt.show()

# %%
plt.plot(conjunto_train[:,0])
plt.show()

# %%
def circuitoRegresor_CodificacionAngular(n_qubits=1):
    qc = QuantumCircuit(n_qubits)
    
    inputs = ParameterVector("inputs",n_qubits)
    pesos = ParameterVector("pesos",2*n_qubits)
    feature_map = QuantumCircuit(n_qubits)
    
    
    
    for i in range(n_qubits):
        feature_map.ry(inputs[i],i)
        
    for i in range(n_qubits-1):
        feature_map.cx(i,i+1)
    
    for i in range(n_qubits):
        feature_map.ry(inputs[i],i)
        
    
    
    ansatz = RealAmplitudes(n_qubits,reps=5)
    #ansatz = QuantumCircuit(n_qubits)
    #for i in range(n_qubits):
    #    ansatz.ry(pesos[i],i)
    #    
    #for i in range(n_qubits-1):
    #    ansatz.cz(i,i+1)
    #
    #for i in range(n_qubits,2*n_qubits):
    #    ansatz.ry(pesos[i],i-n_qubits)
        
    
    
    qc.compose(feature_map, inplace=True)
    qc.compose(QFT(n_qubits, inverse = True), inplace=True)
    qc.compose(ansatz, inplace=True)
    
    
    
    
    return feature_map.parameters, ansatz.parameters, qc, feature_map, ansatz

# %%
inputs, params, circuito, f1, f2 = circuitoRegresor_CodificacionAngular(window)

# %%
# callback function that draws a live plot when the .fit() method is called
def callback_graph(weights, obj_func_eval):
    clear_output(wait=True)
    objective_func_vals.append(obj_func_eval)
    plt.title("Objective function value against iteration")
    plt.xlabel("Iteration")
    plt.ylabel("Objective function value")
    plt.plot(range(len(objective_func_vals)), objective_func_vals)
    plt.show()

# %%
modeloEstimator = EstimatorQNN(
        circuit=circuito, input_params=inputs, weight_params=params
    )

# %%
regressor = NeuralNetworkRegressor(
    neural_network=modeloEstimator,
    loss='absolute_error' ,
    optimizer=COBYLA(maxiter=1250),
    callback=callback_graph
)

# %%
# create empty array for callback to store evaluations of the objective function
objective_func_vals = []
plt.rcParams["figure.figsize"] = (12, 6)

# fit to data
regressor.fit(conjunto_train, objetivo_train)
regressor.score(conjunto_train, objetivo_train)
# Out:
# 0.8249910752373573

# %%
espacio = np.arange(0,objetivo_train.shape[0])
y_ = regressor.predict(conjunto_train)
plt.figure(figsize=(20,10))
plt.plot(espacio ,objetivo_train, marker='o',color='red', label='Verdaderos')
plt.plot(espacio,y_ , color='blue', marker='^',label='Predicciones') 
plt.show()
regressor.weights
# Out:
# array([ 2.26470937, -0.42139528,  0.04863349,  1.33951583,  0.31522787,
#         0.94098093,  1.10611824,  1.35241602, -0.62464632, -0.76627604,
#         0.6696235 ,  0.30106484,  0.27406091,  1.59039307,  0.28756908,
#         0.11724389,  0.84777535,  2.03366964,  0.8489757 ,  2.47247433,
#         0.29538016,  0.97609988,  1.97785171,  0.57475568,  0.53995421,
#        -0.37293412,  0.56742184,  1.03426373, -0.93673966,  1.71271837,
#         0.43347513,  0.94854318,  0.33043438,  0.78496757,  0.06402669,
#         0.44936494,  1.25658199, -0.36363434,  0.37540413,  0.6664149 ,
#         0.57817855,  0.18620458,  0.22460848,  0.66300072,  0.99027458,
#         0.32294798, -0.49216528,  0.20806933,  0.86547958,  0.52590461,
#         0.2140229 ,  0.87699836,  0.29046857,  0.09498701,  1.65751059,
#         1.10535869,  0.89986557,  1.1025619 , -0.08396662,  1.46535274,
#        -0.12334672, -0.17643079,  0.09035527, -0.2487554 , -0.1340624 ,
#        -0.00700991, -0.04365733,  0.32600923, -0.34125614, -0.19490255,
#         0.36628931,  0.12804139])

# %%
np.sum( np.abs(objetivo_train[:] - y_[:]))/(len(objetivo_train))
# Out:
# 48.3101574820684

# %%
vqr = VQR(
    feature_map=f1,
    ansatz=f2,
    optimizer=COBYLA(maxiter=1250),
    callback=callback_graph,
    loss='absolute_error' ,
)

# %%
# create empty array for callback to store evaluations of the objective function
objective_func_vals = []
plt.rcParams["figure.figsize"] = (12, 6)

# fit regressor
vqr.fit(conjunto_train, objetivo_train)

# return to default figsize
plt.rcParams["figure.figsize"] = (6, 4)

# score result
vqr.score(conjunto_train, objetivo_train)
# Out:
# capi_return is NULL
# Call-back cb_calcfc_in__cobyla__user__routines failed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9292/2763316881.py in <module>
#       4
#       5 # fit regressor
# ----> 6 vqr.fit(conjunto_train, objetivo_train)
#       7
#       8 # return to default figsize
#
# ~/anaconda3/lib/python3.9/site-packages/qiskit_machine_learning/algorithms/trainable_model.py in fit(self, X, y)
#     197             self._fit_result = None
#     198
# --> 199         self._fit_result = self._fit_internal(X, y)
#     200         return self
#     201
#
# ~/anaconda3/lib/python3.9/site-packages/qiskit_machine_learning/algorithms/regressors/neural_network_regressor.py in _fit_internal(self, X, y)
#      42             function = MultiClassObjectiveFunction(X, y, self._neural_network, self._loss)
#      43
# ---> 44         return self._minimize(function)
#      45
#      46     def predict(self, X: np.ndarray) -> np.ndarray:  # pylint: disable=invalid-name
#
# ~/anaconda3/lib/python3.9/site-packages/qiskit_machine_learning/algorithms/trainable_model.py in _minimize(self, function)
#     293             )
#     294         else:
# --> 295             optimizer_result = self._optimizer.minimize(
#     296                 fun=objective,
#     297                 x0=initial_point,
#
# ~/anaconda3/lib/python3.9/site-packages/qiskit/algorithms/optimizers/scipy_optimizer.py in minimize(self, fun, x0, jac, bounds)
#     146             self._options["maxfun"] = self._options.pop("maxiter")
#     147
# --> 148         raw_result = minimize(
#     149             fun=fun,
#     150             x0=x0,
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     703                             **options)
#     704     elif meth == 'cobyla':
# --> 705         res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     706                                 **options)
#     707     elif meth == 'slsqp':
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_cobyla_py.py in wrapper(*args, **kwargs)
#      32     def wrapper(*args, **kwargs):
#      33         with _module_lock:
# ---> 34             return func(*args, **kwargs)
#      35     return wrapper
#      36
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_cobyla_py.py in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, **unknown_options)
#     271
#     272     info = np.zeros(4, np.float64)
# --> 273     xopt, info = cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     274                                   rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     275                                   dinfo=info, callback=wrapped_callback)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_cobyla_py.py in calcfc(x, con)
#     259
#     260     def calcfc(x, con):
# --> 261         f = fun(np.copy(x), *args)
#     262         i = 0
#     263         for size, c in izip(cons_lengths, constraints):
#
# ~/anaconda3/lib/python3.9/site-packages/qiskit_machine_learning/algorithms/trainable_model.py in objective(objective_weights)
#     269
#     270         def objective(objective_weights):
# --> 271             objective_value = function.objective(objective_weights)
#     272             self._callback(objective_weights, objective_value)
#     273             return objective_value
#
# ~/anaconda3/lib/python3.9/site-packages/qiskit_machine_learning/algorithms/objective_functions.py in objective(self, weights)
#     113     def objective(self, weights: np.ndarray) -> float:
#     114         # predict is of shape (N, 1), where N is a number of samples
# --> 115         predict = self._neural_network_forward(weights)
#     116         target = np.array(self._y).reshape(predict.shape)
#     117         # float(...) is for mypy compliance
#
# ~/anaconda3/lib/python3.9/site-packages/qiskit_machine_learning/algorithms/objective_functions.py in _neural_network_forward(self, weights)
#     100         ):
#     101             # compute forward and cache the results for re-use in backward
# --> 102             self._last_forward = self._neural_network.forward(self._X, weights)
#     103             # a copy avoids keeping a reference to the same array, so we are sure we have
#     104             # different arrays on the next iteration.
#
# ~/anaconda3/lib/python3.9/site-packages/qiskit_machine_learning/neural_networks/neural_network.py in forward(self, input_data, weights)
#     224         input_, shape = self._validate_input(input_data)
#     225         weights_ = self._validate_weights(weights)
# --> 226         output_data = self._forward(input_, weights_)
#     227         return self._validate_forward_output(output_data, shape)
#     228
#
# ~/anaconda3/lib/python3.9/site-packages/qiskit_machine_learning/neural_networks/estimator_qnn.py in _forward(self, input_data, weights)
#     181         """Forward pass of the neural network."""
#     182         parameter_values_, num_samples = self._preprocess_forward(input_data, weights)
# --> 183         job = self.estimator.run(
#     184             [self._circuit] * num_samples * self.output_shape[0],
#     185             [op for op in self._observables for _ in range(num_samples)],
#
# ~/anaconda3/lib/python3.9/site-packages/qiskit/primitives/base/base_estimator.py in run(self, circuits, observables, parameter_values, **run_options)
#     231         run_opts.update_options(**run_options)
#     232
# --> 233         return self._run(
#     234             circuits,
#     235             observables,
#
# ~/anaconda3/lib/python3.9/site-packages/qiskit/primitives/estimator.py in _run(self, circuits, observables, parameter_values, **run_options)
#     184             self._call, circuit_indices, observable_indices, parameter_values, **run_options
#     185         )
# --> 186         job.submit()
#     187         return job
#
# ~/anaconda3/lib/python3.9/site-packages/qiskit/primitives/primitive_job.py in submit(self)
#      42
#      43         with ThreadPoolExecutor(max_workers=1) as executor:
# ---> 44             future = executor.submit(self._function, *self._args, **self._kwargs)
#      45         self._future = future
#      46
#
# ~/anaconda3/lib/python3.9/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     635
#     636     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 637         self.shutdown(wait=True)
#     638         return False
#     639
#
# ~/anaconda3/lib/python3.9/concurrent/futures/thread.py in shutdown(self, wait, cancel_futures)
#     233         if wait:
#     234             for t in self._threads:
# --> 235                 t.join()
#     236     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# ~/anaconda3/lib/python3.9/threading.py in join(self, timeout)
#    1058
#    1059         if timeout is None:
# -> 1060             self._wait_for_tstate_lock()
#    1061         else:
#    1062             # the behavior of a negative timeout isn't documented, but
#
# ~/anaconda3/lib/python3.9/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1078
#    1079         try:
# -> 1080             if lock.acquire(block, timeout):
#    1081                 lock.release()
#    1082                 self._stop()
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(20,10))
espacio = np.arange(0,conjunto_train.shape[0])
y_ = vqr.predict(conjunto_train)
plt.plot(espacio[:] ,objetivo_train[:], marker='o',color='red', label='Verdaderos')
plt.plot(espacio[:],(y_[:]) , color='blue', marker='^', label='Predicciones') 
plt.show()
np.sum( np.abs(objetivo_train[:] - y_[:]))/(len(objetivo_train))
